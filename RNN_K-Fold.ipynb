# %%
import os
import numpy as np
import pandas as pd

# %% [markdown]
# **path指定**

# %%
base_dir = '/content/drive/MyDrive/kaggle/signLanguage/csv'
train_dir = base_dir + '/train'
test_dir = base_dir + '/test'

# %% [markdown]
# #trainのデータ読み込み

# %%
# dir内のフォルダ数を数える
folder_count = 0
dir = train_dir
for path in os.listdir(dir):
    if os.path.isdir(os.path.join(dir, path)):
        folder_count += 1
print(folder_count)
# Out:
# 20

# %%
for i in range(1,folder_count+1):
    exec_command = 'train_sign' + str(i) + "_path = train_dir + '/sign_" + str(i) + "/'"
    exec(exec_command)
    #print(exec_command)

# %%
train_sign1_path  # パス確認
# Out:
# '/content/drive/MyDrive/kaggle/signLanguage/csv/train/sign_1/'

# %%
frame = 60
Y=[]
for i in range(1,folder_count+1):
    # sign1-sign20のpathを指定
    path_exec_command = 'path = train_sign' + str(i) + '_path'
    exec(path_exec_command)
    #print(path_exec_command)

    files=os.listdir(path)
    #print(files)
    lists=[]  # 同じsignのデータを3次元listに格納する
    for file in files:
        #print(file)
        df = pd.read_csv(path+file, index_col=0)

        df = df.iloc[:,1404:]  # 顔の情報を削除468x3
        df = df.iloc[:,63:]  # 左手の情報を削除21x3

        df = df.fillna(0.1)  # 欠損データ

        # フレームの補完．60フレームに足りない場合は最後のフレームで補完     
        if len(df) < frame:
            for f in range(len(df), frame):
                df=df.append(df.tail(1))
        #print(df)

        lists.append(df.values[:frame, :].tolist())  # signごとに結合
        Y.append(i - 1)# ラベル
    csv_exec_command = 'train_sign' + str(i) + '= np.array(lists)'
    exec(csv_exec_command)
    #print(csv_exec_command)

# %%
print(train_sign1.shape) # 動画数,フレーム数,特徴量
# Out:
# (40, 60, 162)

# %%
from keras.utils import np_utils

Y = np.array(Y)
Y = np_utils.to_categorical(Y)
Y.shape
# Out:
# (800, 20)

# %% [markdown]
# **trainデータの結合**

# %%
X=train_sign1
for i in range(2, folder_count+1):
    exec_command = 'X = np.concatenate([X, train_sign'+ str(i) +'], 0)'
    #print(exec_command)
    exec(exec_command)

print(X.shape)
# Out:
# (800, 60, 162)

# %% [markdown]
# #モデルの構成

# %%
from keras.layers.advanced_activations import LeakyReLU
from keras import layers
from keras import models
from keras.layers.recurrent import SimpleRNN, LSTM
from keras.models import Sequential
from keras.layers import Dense, Dropout,LeakyReLU
from keras import optimizers

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import Adam

def build_model():
    model = Sequential()
    model.add(LSTM(64, return_sequences=False, activation='tanh', input_shape=X.shape[1:]))
    model.add(Dense(Y.shape[1], activation='softmax'))
    
    #model.summary()    

    opt = Adam(lr=0.001, decay=1e-6)
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=["accuracy"])

    return model

# %% [markdown]
# #k-foldを使ったデータの分割と学習

# %% [markdown]
# 参考：https://zenn.dev/monda/articles/kaggle-cv-template

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping

FOLD = 5
EPOCH = 30
BATCH_SIZE = None

valid_scores = []
models = []
kf = KFold(n_splits=FOLD, shuffle=True, random_state=42)

for fold, (train_indices, valid_indices) in enumerate(kf.split(X)):
    X_train, X_valid = X[train_indices], X[valid_indices]
    y_train, y_valid = Y[train_indices], Y[valid_indices]

    model = build_model()

    # rlr = ReduceLROnPlateau(monitor='val_loss',
    #                         factor=0.1,
    #                         patience=3,
    #                         verbose=0,
    #                         min_delta=1e-4,
    #                         mode='max')
    # ckp = ModelCheckpoint(f'model_{fold}.hdf5',
    #                       monitor='val_loss',
    #                       verbose=0,
    #                       save_best_only=True,
    #                       save_weights_only=True,
    #                       mode='max')
    # es = EarlyStopping(monitor='val_loss',
    #                    min_delta=1e-4,
    #                    patience=100,
    #                    mode='max',
    #                    baseline=None,
    #                    restore_best_weights=True,
    #                    verbose=0)

    h = model.fit(X_train, y_train,
              validation_data=(X_valid, y_valid),
              epochs=EPOCH,
              batch_size=BATCH_SIZE,
              verbose=1)

    y_valid_pred = model.predict(X_valid)
    score = mean_absolute_error(y_valid, y_valid_pred)
    print(f'fold {fold} MAE: {score}')
    valid_scores.append(score)

    models.append(model)

cv_score = np.mean(valid_scores)
print(f'CV score: {cv_score}')  # 平均絶対誤差
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/30
# 20/20 [==============================] - 4s 93ms/step - loss: 2.9449 - accuracy: 0.1156 - val_loss: 2.8540 - val_accuracy: 0.1437
# Epoch 2/30
# 20/20 [==============================] - 1s 75ms/step - loss: 2.6380 - accuracy: 0.2219 - val_loss: 2.5942 - val_accuracy: 0.1187
# Epoch 3/30
# 20/20 [==============================] - 1s 73ms/step - loss: 2.4070 - accuracy: 0.2656 - val_loss: 2.3247 - val_accuracy: 0.3125
# Epoch 4/30
# 20/20 [==============================] - 1s 73ms/step - loss: 2.2581 - accuracy: 0.3000 - val_loss: 2.2020 - val_accuracy: 0.2875
# Epoch 5/30
# 20/20 [==============================] - 1s 74ms/step - loss: 2.0150 - accuracy: 0.3953 - val_loss: 2.0220 - val_accuracy: 0.3875
# Epoch 6/30
# 20/20 [==============================] - 2s 76ms/step - loss: 1.8907 - accuracy: 0.4344 - val_loss: 1.8797 - val_accuracy: 0.4187
# Epoch 7/30
# 20/20 [==============================] - 1s 73ms/step - loss: 1.7490 - accuracy: 0.4594 - val_loss: 1.8378 - val_accuracy: 0.4187
# Epoch 8/30
# 20/20 [==============================] - 1s 73ms/step - loss: 1.6539 - accuracy: 0.5188 - val_loss: 1.6090 - val_accuracy: 0.5375
# Epoch 9/30
# 20/20 [==============================] - 1s 74ms/step - loss: 1.4189 - accuracy: 0.5938 - val_loss: 1.5317 - val_accuracy: 0.5125
# Epoch 10/30
# 20/20 [==============================] - 1s 74ms/step - loss: 1.9906 - accuracy: 0.4266 - val_loss: 2.4449 - val_accuracy: 0.2875
# Epoch 11/30
# 20/20 [==============================] - 1s 74ms/step - loss: 2.0157 - accuracy: 0.3906 - val_loss: 1.8133 - val_accuracy: 0.4688
# Epoch 12/30
# 20/20 [==============================] - 1s 74ms/step - loss: 1.6666 - accuracy: 0.5078 - val_loss: 1.6888 - val_accuracy: 0.3875
# Epoch 13/30
# 20/20 [==============================] - 1s 75ms/step - loss: 1.4482 - accuracy: 0.5641 - val_loss: 1.3818 - val_accuracy: 0.6125
# Epoch 14/30
# 20/20 [==============================] - 1s 73ms/step - loss: 1.3062 - accuracy: 0.6062 - val_loss: 1.3334 - val_accuracy: 0.6062
# 20/20 [==============================] - 1s 75ms/step - loss: 1.8493 - accuracy: 0.4359 - val_loss: 1.9136 - val_accuracy: 0.4313
# Epoch 7/30
# 20/20 [==============================] - 1s 75ms/step - loss: 1.6726 - accuracy: 0.4641 - val_loss: 1.6573 - val_accuracy: 0.4938
# Epoch 8/30
# 20/20 [==============================] - 2s 78ms/step - loss: 1.5255 - accuracy: 0.5141 - val_loss: 1.5587 - val_accuracy: 0.6062
# Epoch 9/30
# 20/20 [==============================] - 2s 77ms/step - loss: 1.4301 - accuracy: 0.5969 - val_loss: 1.6748 - val_accuracy: 0.5625
# Epoch 10/30
# 20/20 [==============================] - 2s 76ms/step - loss: 1.3758 - accuracy: 0.5719 - val_loss: 1.5185 - val_accuracy: 0.5437
# Epoch 11/30
# 20/20 [==============================] - 1s 74ms/step - loss: 1.2297 - accuracy: 0.6703 - val_loss: 1.3093 - val_accuracy: 0.5938
# Epoch 12/30
# 20/20 [==============================] - 1s 71ms/step - loss: 1.1115 - accuracy: 0.6891 - val_loss: 1.2457 - val_accuracy: 0.6250
# Epoch 13/30
# 20/20 [==============================] - 1s 72ms/step - loss: 1.1170 - accuracy: 0.6313 - val_loss: 1.2550 - val_accuracy: 0.6500
# Epoch 14/30
# 20/20 [==============================] - 2s 76ms/step - loss: 1.0221 - accuracy: 0.6969 - val_loss: 1.0794 - val_accuracy: 0.7125
# Epoch 15/30
# 20/20 [==============================] - 1s 73ms/step - loss: 1.3374 - accuracy: 0.5734 - val_loss: 1.4621 - val_accuracy: 0.5625
# Epoch 16/30
# 20/20 [==============================] - 1s 75ms/step - loss: 1.1243 - accuracy: 0.6672 - val_loss: 1.1469 - val_accuracy: 0.7312
# Epoch 17/30
# 20/20 [==============================] - 1s 75ms/step - loss: 0.9726 - accuracy: 0.7203 - val_loss: 1.0124 - val_accuracy: 0.7250
# Epoch 18/30
# 20/20 [==============================] - 1s 73ms/step - loss: 0.7980 - accuracy: 0.7719 - val_loss: 0.9237 - val_accuracy: 0.7750
# Epoch 19/30
# 20/20 [==============================] - 1s 70ms/step - loss: 0.7202 - accuracy: 0.7922 - val_loss: 0.9382 - val_accuracy: 0.7312
# Epoch 20/30
# 20/20 [==============================] - 1s 70ms/step - loss: 0.7708 - accuracy: 0.7797 - val_loss: 0.8623 - val_accuracy: 0.8188
# Epoch 21/30
# 20/20 [==============================] - 1s 70ms/step - loss: 0.6776 - accuracy: 0.8000 - val_loss: 0.7935 - val_accuracy: 0.8438
# Epoch 22/30
# 20/20 [==============================] - 1s 74ms/step - loss: 0.5635 - accuracy: 0.8641 - val_loss: 0.7242 - val_accuracy: 0.8250
# Epoch 23/30
# 20/20 [==============================] - 2s 76ms/step - loss: 0.5161 - accuracy: 0.8609 - val_loss: 0.7455 - val_accuracy: 0.8125
# Epoch 24/30
# 20/20 [==============================] - 1s 75ms/step - loss: 0.5276 - accuracy: 0.8531 - val_loss: 0.7804 - val_accuracy: 0.8062
# Epoch 25/30
# 20/20 [==============================] - 2s 78ms/step - loss: 0.5433 - accuracy: 0.8469 - val_loss: 0.7773 - val_accuracy: 0.8062
# Epoch 26/30
# 20/20 [==============================] - 2s 76ms/step - loss: 0.5199 - accuracy: 0.8391 - val_loss: 0.7618 - val_accuracy: 0.8062
# Epoch 27/30
# 20/20 [==============================] - 2s 75ms/step - loss: 0.5726 - accuracy: 0.8250 - val_loss: 0.7545 - val_accuracy: 0.8313
# Epoch 28/30
# 20/20 [==============================] - 1s 75ms/step - loss: 0.4524 - accuracy: 0.8719 - val_loss: 0.7271 - val_accuracy: 0.8062
# Epoch 29/30
# 20/20 [==============================] - 2s 75ms/step - loss: 0.4196 - accuracy: 0.8641 - val_loss: 0.7613 - val_accuracy: 0.7937
# Epoch 30/30
# 20/20 [==============================] - 2s 76ms/step - loss: 0.4082 - accuracy: 0.8734 - val_loss: 0.6418 - val_accuracy: 0.8438
# fold 3 MAE: 0.030074838548898697
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/30
# 20/20 [==============================] - 4s 93ms/step - loss: 2.9745 - accuracy: 0.0953 - val_loss: 2.8979 - val_accuracy: 0.1312
# Epoch 2/30
# 20/20 [==============================] - 2s 75ms/step - loss: 2.7565 - accuracy: 0.1922 - val_loss: 2.7494 - val_accuracy: 0.1750
# Epoch 3/30
# 20/20 [==============================] - 2s 77ms/step - loss: 2.5210 - accuracy: 0.2688 - val_loss: 2.4105 - val_accuracy: 0.3125
# Epoch 4/30
# 20/20 [==============================] - 1s 72ms/step - loss: 2.2728 - accuracy: 0.3422 - val_loss: 2.2204 - val_accuracy: 0.3313
# Epoch 5/30
# 20/20 [==============================] - 1s 68ms/step - loss: 2.0366 - accuracy: 0.4203 - val_loss: 1.9221 - val_accuracy: 0.4938
# Epoch 6/30
# 20/20 [==============================] - 1s 72ms/step - loss: 1.7928 - accuracy: 0.4906 - val_loss: 1.7390 - val_accuracy: 0.4688
# Epoch 7/30
# 20/20 [==============================] - 1s 74ms/step - loss: 1.5676 - accuracy: 0.5406 - val_loss: 1.4810 - val_accuracy: 0.5688
# Epoch 8/30
# 20/20 [==============================] - 1s 75ms/step - loss: 1.4868 - accuracy: 0.5391 - val_loss: 1.5140 - val_accuracy: 0.4812
# Epoch 9/30
# 20/20 [==============================] - 2s 76ms/step - loss: 1.4809 - accuracy: 0.5406 - val_loss: 1.3740 - val_accuracy: 0.5188
# Epoch 10/30
# 20/20 [==============================] - 2s 76ms/step - loss: 1.2551 - accuracy: 0.6172 - val_loss: 1.2363 - val_accuracy: 0.5625
# Epoch 11/30
# 20/20 [==============================] - 1s 71ms/step - loss: 1.1367 - accuracy: 0.6578 - val_loss: 1.1770 - val_accuracy: 0.6500
# Epoch 12/30
# 20/20 [==============================] - 1s 69ms/step - loss: 1.0528 - accuracy: 0.6766 - val_loss: 1.2002 - val_accuracy: 0.6000
# Epoch 13/30
# 20/20 [==============================] - 1s 74ms/step - loss: 1.1080 - accuracy: 0.6469 - val_loss: 1.1923 - val_accuracy: 0.5938
# Epoch 14/30
# 20/20 [==============================] - 2s 77ms/step - loss: 1.0098 - accuracy: 0.6531 - val_loss: 1.0103 - val_accuracy: 0.6875
# Epoch 15/30
# 20/20 [==============================] - 2s 78ms/step - loss: 0.8887 - accuracy: 0.7188 - val_loss: 1.0275 - val_accuracy: 0.6812
# Epoch 16/30
# 20/20 [==============================] - 2s 76ms/step - loss: 0.8994 - accuracy: 0.7109 - val_loss: 0.8839 - val_accuracy: 0.6687
# Epoch 17/30
# 20/20 [==============================] - 1s 74ms/step - loss: 0.8238 - accuracy: 0.7234 - val_loss: 1.5267 - val_accuracy: 0.5063
# Epoch 18/30
# 20/20 [==============================] - 2s 75ms/step - loss: 1.0452 - accuracy: 0.6750 - val_loss: 0.9627 - val_accuracy: 0.6625
# Epoch 19/30
# 20/20 [==============================] - 1s 75ms/step - loss: 0.7866 - accuracy: 0.7531 - val_loss: 0.9251 - val_accuracy: 0.6875
# Epoch 20/30
# 20/20 [==============================] - 1s 75ms/step - loss: 0.6637 - accuracy: 0.7922 - val_loss: 0.7000 - val_accuracy: 0.8000
# Epoch 21/30
# 20/20 [==============================] - 2s 76ms/step - loss: 0.5838 - accuracy: 0.8203 - val_loss: 0.6837 - val_accuracy: 0.8000
# Epoch 22/30
# 20/20 [==============================] - 2s 76ms/step - loss: 0.5687 - accuracy: 0.8359 - val_loss: 0.5777 - val_accuracy: 0.8625
# Epoch 23/30
# 20/20 [==============================] - 1s 74ms/step - loss: 0.5474 - accuracy: 0.8453 - val_loss: 0.5877 - val_accuracy: 0.8188
# Epoch 24/30
# 20/20 [==============================] - 1s 75ms/step - loss: 0.5789 - accuracy: 0.8094 - val_loss: 0.6626 - val_accuracy: 0.8062
# Epoch 25/30
# 20/20 [==============================] - 1s 74ms/step - loss: 0.5228 - accuracy: 0.8391 - val_loss: 0.6391 - val_accuracy: 0.8125
# Epoch 26/30
# 20/20 [==============================] - 1s 74ms/step - loss: 0.4551 - accuracy: 0.8594 - val_loss: 0.5195 - val_accuracy: 0.8188
# Epoch 27/30
# 20/20 [==============================] - 1s 71ms/step - loss: 0.3924 - accuracy: 0.8766 - val_loss: 0.5596 - val_accuracy: 0.8062
# Epoch 28/30
# 20/20 [==============================] - 1s 74ms/step - loss: 0.3578 - accuracy: 0.8984 - val_loss: 0.4483 - val_accuracy: 0.8438
# Epoch 29/30
# 20/20 [==============================] - 2s 76ms/step - loss: 0.4240 - accuracy: 0.8516 - val_loss: 0.5363 - val_accuracy: 0.8188
# Epoch 30/30
# 20/20 [==============================] - 2s 75ms/step - loss: 0.4501 - accuracy: 0.8531 - val_loss: 0.4981 - val_accuracy: 0.7937
# fold 4 MAE: 0.029377644881606102
# CV score: 0.031348906457424164

# %% [markdown]
# #trainデータの分割と学習

# %%
# from sklearn.model_selection import train_test_split

# train_x, val_x, train_y, val_y = train_test_split(X, Y, test_size=0.1)

# %%
# model = build_model()

# h=model.fit(train_x, 
#             train_y, 
#             epochs= 325, 
#             verbose=1, 
#             validation_data=(val_x, val_y))

# %% [markdown]
# #グラフ表示

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_history(history):
    # print(history.history.keys())

    # 精度の履歴をプロット
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend(['acc', 'val_acc'], loc='lower right')
    plt.show()

    # 損失の履歴をプロット
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['loss', 'val_loss'], loc='lower right')
    plt.show()

plot_history(h)

# %%
# 学習結果を保存する
hdf5_file = os.path.join(base_dir, '../LSTM.hdf5')
model.save(hdf5_file)
